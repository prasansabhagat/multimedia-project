# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
#to see the images in the notebook itself
# %matplotlib inline

# %%
from  PIL import Image

# %%
pic = Image.open('butterfly.jpg')
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_array = np.asarray(pic)
type(pic_array)
# Out:
# numpy.ndarray

# %%
pic_array.shape
# Out:
# (1000, 1000, 3)

# %%
plt.imshow(pic_array)

# %%
pic_red = pic_array.copy()

# %%
pic_red.shape
# Out:
# (1000, 1000, 3)

# %%
#R G B
#plt.imshow(pic_red[:,:,0])
#plt.imshow(pic_red[:, :,1])
plt.imshow(pic_red[:,:,2], cmap='gray')

# %%
pic_red[:,:,0]
# Out:
# array([[ 45,  45,  45, ...,  79,  79,  79],
#        [ 45,  45,  46, ...,  79,  79,  79],
#        [ 45,  46,  46, ...,  79,  79,  79],
#        ...,
#        [116, 116, 117, ..., 115, 117, 117],
#        [116, 116, 117, ..., 115, 117, 117],
#        [116, 116, 117, ..., 115, 117, 117]], dtype=uint8)

# %%
#green channel
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,0] = 0
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)

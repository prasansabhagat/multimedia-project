# %% [markdown]
# OpenCV  is open source computer vision, it is a library of programming functions mainly aimed at real time computer vision.
#
# It was created by INTEL in 1999, written in c++.

# %%
import numpy as np
import matplotlib.pyplot as plt
#only for jupyter notebook 
#%matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('butterfly.jpg')
img
# Out:
# array([[[ 23,  66,  45],
#         [ 23,  66,  45],
#         [ 23,  66,  45],
#         ...,
#         [ 42,  98,  79],
#         [ 42,  98,  79],
#         [ 42,  98,  79]],
#
#        [[ 23,  66,  45],
#         [ 23,  66,  45],
#         [ 24,  67,  46],
#         ...,
#         [ 42,  98,  79],
#         [ 42,  98,  79],
#         [ 42,  98,  79]],
#
#        [[ 23,  66,  45],
#         [ 24,  67,  46],
#         [ 24,  67,  46],
#         ...,
#         [ 42,  98,  79],
#         [ 42,  98,  79],
#         [ 42,  98,  79]],
#
#        ...,
#
#        [[ 71, 135, 116],
#         [ 71, 135, 116],
#         [ 72, 136, 117],
#         ...,
#         [ 61, 139, 115],
#         [ 64, 139, 117],
#         [ 64, 139, 117]],
#
#        [[ 71, 135, 116],
#         [ 71, 135, 116],
#         [ 72, 136, 117],
#         ...,
#         [ 61, 139, 115],
#         [ 64, 139, 117],
#         [ 64, 139, 117]],
#
#        [[ 71, 135, 116],
#         [ 71, 135, 116],
#         [ 72, 136, 117],
# ...

# %%
#always check for the type of image as open cv does not gives error for wrong path, so check the type of image first!! If the path is wrong the type will be 'NoneType'!
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1000, 1000, 3)

# %%
plt.imshow(img)

# %% [markdown]
# MATPLOTLIB --> Red Green Blue
#
# OPENCV     --> Blue Green Red
